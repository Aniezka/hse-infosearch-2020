# %% [markdown]
# ## Лекция 2  BM5

# %% [markdown]
# ### TfidfVectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

# инициализируем
vectorizer = TfidfVectorizer()

# составляем корпус документов
corpus = [
  'слово1 слово2 слово3',
  'слово2 слово3',
  'слово1 слово2 слово1',
  'слово4'
]

# считаем
X = vectorizer.fit_transform(corpus)
 
# получится следующая структура:
#        |  слово1  |  слово2  |  слово3  |  слово4
# текст1 |   0.6    |    0.5   |   0.6    |    0
# текст2 |   0      |    0.6   |   0.8    |    0
# текст3 |   0.9    |    0.4   |   0      |    0
# текст4 |   0      |    0     |   0      |    1
 
# чтобы получить сгенерированный словарь, из приведенной структуры TfidfVectorizer
# порядок совпадает с матрицей
vectorizer.get_feature_names()  # ['слово1', 'слово2', 'слово3', 'слово4']
 
# чтобы узнать индекс токена в словаре
vectorizer.vocabulary_.get('слово3') # вернет 2
 
# показать матрицу
X.toarray()
 
# теперь можно быстро подсчитать вектор для нового документа
new_doc = vectorizer.transform(['слово1 слово4 слово4']).toarray()  # результат [[0.36673901, 0, 0, 0.93032387]]

# %% [markdown]
# ## Функция ранжирования bm25

# %% [markdown]
# Для обратного индекса есть общепринятая формула для ранжирования *Okapi best match 25* ([Okapi BM25](https://ru.wikipedia.org/wiki/Okapi_BM25)).
# Пусть дан запрос $Q$, содержащий слова  $q_1, ... , q_n$, тогда функция BM25 даёт следующую оценку релевантности документа $D$ запросу $Q$:
#
# $$ score(D, Q) = \sum_{i}^{n} \text{IDF}(q_i)*\frac{TF(q_i,D)*(k+1)}{TF(q_i,D)+k(1-b+b\frac{l(d)}{avgdl})} $$
# где
# >$TF(q_i,D)$ - частота слова $q_i$ в документе $D$
# $l(d)$ - длина документа (количество слов в нём)
# *avgdl* — средняя длина документа в коллекции
# $k$ и $b$ — свободные коэффициенты, обычно их выбирают как $k$=2.0 и $b$=0.75
# $$$$
# $\text{IDF}(q_i)$ - это модернизированная версия IDF:
# $$\text{IDF}(q_i) = \log\frac{N-n(q_i)+0.5}{n(q_i)+0.5},$$
# >> где $N$ - общее количество документов в коллекции
# $n(q_i)$ — количество документов, содержащих $q_i$

# %%
### реализуйте эту функцию ранжирования 
import collections
import string
import math
import pandas as pd
import numpy as np

from pymorphy2 import MorphAnalyzer
from razdel import tokenize
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer

morph = MorphAnalyzer()
stop = set(stopwords.words('russian'))
k = 2.0
b = 0.75


def my_preprocess(text: str):
    text = str(text)
    text = text.replace("\n", " ").replace('/', ' ')
    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
    tokenized_text = list(tokenize(text))
    lemm = [morph.parse(i.text)[0].normal_form for i in tokenized_text]
    words = [i for i in lemm if i not in stop]
    return " ".join(words)

# %% [markdown]
# ### __Задача 1__:
# Реализуйте поиск с метрикой *TF-IDF* через умножение матрицы на вектор.
# Что должно быть в реализации:
# - проиндексированная база, где каждый документ представлен в виде вектора TF-IDF
# - функция перевода входяшего запроса в вектор по метрике TF-IDF
# - ранжирование докуменов по близости к запросу по убыванию
#
# В качестве корпуса возьмите корпус вопросов в РПН по Covid2019. Он состоит из:
# > файл **answers_base.xlsx** - база ответов, у каждого ответа есть его номер, тематика и примеры вопросов, которые могут быть заданы к этому ответу. Сейчас проиндексировать надо именно примеры вопросов в качестве документов базы. Понимаете почему?
#
# > файл **queries_base.xlsx** - вопросы юзеров, к каждому из которых проставлен номер верного ответа из базы. Разделите эти вопросы в пропорции 70/30 на обучающую (проиндексированную как база) и тестовую (как запросы) выборки.

# %% [markdown]
# ##### Функции для векторизации единичного запроса

# %%
def vec_tfidf(doc, vectorizer):
    doc = my_preprocess(doc)
    return vectorizer.transform([doc]).toarray()

# %% [markdown]
# ##### Считаем данные, переименуем столбцы (для удобства), добавим 70% queries_base (путём разбиения на test/train - 0.3/0.7) и получим матрицу эмбеддингов

# %%
answers_df = pd.read_excel("answers_base.xlsx")
questions_df = pd.read_excel("queries_base.xlsx")

# %%
full_corpus = []
vectorizer = TfidfVectorizer()

answers_df.rename(columns={'Текст вопросов': 'text', 'Номер связки': 'join_num'}, inplace=True)
questions_df.rename(columns={'Текст вопроса': 'text', 'Номер связки\n': 'join_num'}, inplace=True)

train, test = train_test_split(questions_df, test_size=0.3)

answers_quest = pd.concat([answers_df, train])

for quest in answers_quest['text']:
    full_corpus.append(my_preprocess(quest))
    
X_train = vectorizer.fit_transform(full_corpus)
X_train.shape
# Out:
# (1652, 7417)

# %% [markdown]
# ##### Возьмём случайный запрос из тестовой выборки

# %%
query = vec_tfidf(test.text.values[9], vectorizer)
print(test.text.values[9])
# Out:
# Где в Ростове на Дону мы можем сделать обязательный тест на коронавирус по медицскомк полису без оплаты
# --
# Отправлено из Mail.ru для Android четверг, 03 сентября 2020г., 13:12 +03:00 от covid@78cge.ru :
#
# >Добрый день, Ваше сообщение зарегистрировано в системе под номером: 10853
# >Ваш вопрос:
# >У вас сказано, что добровольное взятие анализа платное, и взятие анализа без медицинских показаний тоже платное. А если у нас нет показаний и нас обязывают пройти этот тест - это же уже не добровольное прохождение, подскажите пожалуйста, где в Ростове на Дону мы сможем пройти обязательное тестирование по полису? Жду ответ -- Отправлено из Mail.ru для Android четверг, 03 сентября 2020г., 12:54 +03:00 от covid@78cge.ru :> Добрый день, Ваше сообщение зарегистрировано в системе под номером: 10844> Ваш вопрос:> Здравствуйте, мы 6 дней были в отпуске, а по приезду узнали об обязательном прохождении теста на коронавирус. Мы хотим его пройти, но у нас нет средств, а в поликлинике по страховому полису нам отказали. Завтра нужно в госуслуги уже подкрепить справку, о том, что мы не больны, но такой возможности в материальном плане у нас нет. Как нам поступить правильно, чтобы не получить штрафов за отсутствие справки, или как пройти тест без оплаты, возможно есть способ о котором мы не знаем? Жду ответ -- Отправлено из Mail.ru для Android > Ответ:> На основании подпункта 1.4 пункта 1 постановления Главного государственного санитарного врача РФ от 30 марта 2020 г. № 9 "О дополнительных мерах по недопущению распространения COVID-2019", организация лабораторной диагностики граждан в субъектах Российской Федерации с привлечением всех лабораторий организаций вне зависимости от их организационно-правовой формы, возложена на руководителей высшего исполнительного органа государственной власти субъектов Российской Федерации (регионы РФ). >   В настоящее время срок ПЦР-диагностики на новую коронавирусную инфекцию в соответствии с нормативно-правовыми актами Российской Федерации не установлен. Проведение анализа обычно занимает 1,5-2 дня. >   Однако, в ряде регионов Российской Федерации, из-за большого объема поступающих проб в лаборатории, сроки могут быть увеличены.>  >   Тестирование должны проходить в обязательном порядке все прибывшие из-за границы на территорию России после начала регулярного авиасообщения:>   - иностранные граждане - предоставляют медицинский документ (на русском или английском языках) об отрицательном ПЦР тесте на COVID - 19, выполненном не ранее чем за три дня до прибытия в Россию или медицинский документ, подтверждающий выявление антител иммуноглобулина G (при наличии). При отсутствии результатов отрицательного ПЦР теста - проходят ПЦР тест - в течении 3х дней с даты прибытия в Россию;>   - граждане РФ должны пройти ПЦР тест на ковид - в течении 3-х дней с даты прибытия.>   В случае любого ухудшения состояния здоровья гражданин должен незамедлительно обратиться за медицинской помощью по месту жительства без посещения медицинской организации и сообщить информацию о прибытии из-за границы.>   В отношении всех прибывших граждан заполненные анкеты в суточный срок передаются в территориальный орган Роспотребнадзора по месту дальнейшего следования прибывших.>  >   Кроме этого, тест на наличие коронавируса в обязательном порядке назначается по показаниям и исключительно врачом медицинской организации. Обязательному обследованию подлежат с учетом приоритетов, установленных санитарными правилами "СП 3.1.3597-20 Профилактика новой коронавирусной инфекции (COVID-19)": >   1) контактирующие с больным COVID–19;>   2) больным с диагнозом "внебольничная пневмония";>   3) лица, старше 65 лет, обратившимися за помощью с симптомами респираторного заболевания;>   4) медицинские работники, имеющие риски инфицирования COVID–19.>   Медицинские работники подлежат обязательному тестированию на коронавирусную инфекцию, поскольку они осуществляю работу и взаимодействие с носителями новой коронавирусной инфекции. Как правило, медицинских работников на постоянной основе тестирует работодатель - та медицинская организация, в которой работает медицинский сотрудник.>   Стоит учитывать, что в ряде регионов РФ нормативно-правовым актом органа здравоохранения (комитета, департамента, министерства) уточнен порядок тестирования медицинских работников (по в ...
# >Ответ:
# >Ниже будет представлена информация о всех необходимых действиях для прибывающих в Россию.
# >  Иностранным гражданам и лицам без гражданства:
# >  -при посадке в выполняющее международные воздушные перевозки воздушное судно, следующее в пункт назначения на территории Российской Федерации, в том числе в целях транзитного проезда через территорию Российской Федерации, и при пересечении Государственной границы Российской Федерации обеспечить наличие при себе медицинского документа (на русском или английском языках), подтверждающего отрицательный результат лабораторного исследования материала на COVID-19 методом полимеразной цепной реакции (ПЦР), отобранного не ранее чем за три календарных дня до прибытия на территорию Российской Федерации;
# >  -до прибытия на территорию Российской Федерации в целях обеспечения санитарно-карантинного контроля в пунктах пропуска через Государственную границу Российской Федерации обеспечить заполнение анкеты прибывающего на территорию Российской Федерации (рекомендуемый образец размещен на официальном сайте Роспотребнадзора).
# >  В случае невозможности представить медицинский документ на русском или английском языках допускается его представление на официальном языке государства регистрации организации, выдавшей такой медицинский документ, с переводом на русский язык, верность которого засвидетельствована консульским должностным лицом Российской Федерации.
# >
# >  Гражданам Российской Федерации, прибывающим на территорию Российской Федерации воздушным транспортом (за исключением членов экипажа воздушного судна, осуществляющего воздушную перевозку):
# >  -Обеспечить заполнение анкеты прибывающего на территорию Российской Федерации до прибытия на территорию Российской Федерации в целях обеспечения санитарно-карантинного контроля в пунктах пропуска через Государственную границу Российской Федерации.
# >  В целях оперативного прохождения санитарно-карантинного контроля в пунктах пропуска через Государственную границу Российской Федерации обеспечить заполнение на Едином портале государственных и муниципальных услуг (далее - ЕПГУ) ( https://www.gosuslugi.ru ) анкеты для прибывающего в Российскую Федерацию в электронном виде "Регистрация прибывающих в Российскую Федерацию" ( https://www.gosuslugi.ru/394604 ) до вылета в Российскую Федерацию (при приобретении билета, но не позднее регистрации на рейс).
# >  В течение трех календарных дней со дня прибытия на территорию Российской Федерации пройти лабораторное исследование на COVID-19 методом ПЦР и разместить информацию о результате лабораторного исследования на COVID-19 методом ПЦР в ЕПГУ, заполнив форму "Предоставление сведений о результатах теста на новую коронавирусную инфекцию для прибывающих на территорию Российской Федерации" ( https://www.gosuslugi.ru/400705/1 ).
# >  Несовершеннолетним можно зарегистрировать аккаунт на портале гос услуг. Стандартный профиль для детей старше 14 лет (требуется паспорт и СНИЛС) или упрощенный для детей до 14 лет (без подтверждающих документов). Анкеты на детей при сопровождении родителей создаются в личном кабинете родителя (можно активировать поля для ввода информации о детях). Дети следующие без родителей или сопровождающих лиц должны заполнить анкеты и загружать сведения о тестировании в личный аккаунт.
# >
# >  Граждане России в течении 3-х дней с момента прибытия в Россию должны пройти лабораторное исследование и загрузить результаты обследования на коронавирус (ПЦР-тест) в форму на портале Госуслуг. Это предусмотрено постановлением Главного государственного санитарного врача Российской Федерации от 18.03.2020 № 7 в редакции постановления от 27.07.2020 № 22. ПЦР-тестирование обязаны проходить все граждане РФ (в том числе, дети), которые въезжают на территорию Российской Федерации. Срок выполнения ПЦР-тестирования установлен на федеральном уровне и не может быть нарушен. Рекомендуем заранее записаться на сдачу ПЦР-теста на коронавирус (чтобы соблюсти установленный срок предоставления результатов). В ряде регионов ПЦР-тест можно сдать бесплатно, также по записи. Как правило, государственные поликлиники направляют на тестирование при наличии симптомов или по требованию Роспотребнадзора. В остальных случаях исследования проводятся на коммерческой основе. В ряде регионов услуга ПЦР теста доступна на территории аэропортов (в помещениях медицинского пункта). О возможности сдачи в аэропорту можно уточнить по телефонам справочных служб аэропортов (размещены на сайтах).
# >
# >  При положительном результате ПЦР теста на коронавирус, а также при появления любого ухудшения состояния здоровья в течение 14 календарных дней со дня прибытия на территорию России нужно незамедлительно обращаться за медицинской помощью по месту жительства (пребывания) БЕЗ посещения медицинских организаций. Обеспечить соблюдение требований по обязательной изоляции по месту жительства или фактическому пребыванию (в изолированном помещении, позволяющем исключить контакты с членами семьи и другими лицами, не подвергнутыми изоляции). Информация о положительных результатах передается в территориальные органы Роспотребнадзора и медицинские организации (поликлиники) по месту жительства для организации профилактических мер и медицинского наблюдения.
# >  В случае подгрузки на портал гос.услуг результатов ПЦР-тестирования в течении обозначенного срока и он является отрицательным делать ничего не нужно. В этом случае гражданин не обязан соблюдать изоляцию. Кроме того, отсутствует требование об изоляции и до момента получения результата теста при хорошем самочувствии.
# >  ВАЖНО: Граждане РФ не могут провести тестирование в иностранном государстве, с целью предоставления результатов в качестве выполненной обязанности, предусмотренной санитарно-эпидемиологическими нормами). Актуальная информация о перечне коммерческих лабораторий, допущенных к проведению исследований на COVID-19 лиц, не имеющих признаков инфекционного заболевания и не находящихся в прямом контакте с больным новой коронавирусной инфекции (COVID-19) размещен на сайте Роспотребнадзора (главная страница) - О новой коронавирусной инфекции - Перечень лабораторий, допущенных к исследованиям на новую коронавирусную инфекцию. Полная информация о стоимости и условиях доступна на сайтах организаций.
# >  За невыполнение обязанности ПЦР-тестирования в течении 3-х дней и отсутствие подгруженных результатов ПЦР-тестирования на граждан может быть наложен штраф в размере от 15000 до 40000 рублей (статья 6.3 КоАП РФ). Территориальные органы Роспотребнадзора уведомляют граждан о данном требовании и затем осуществляют контроль, в случае нарушения сроков - составляют протокол об административном правонарушении. В случае выявления должностными лицами нарушений обязательных требований Вас вызовут для ознакомления с протоколом об административном правонарушении. Уточнить и задать интересующие вопросы можно будет у должностного лица Управление Роспотребнадзора по вашему региону после вызова. Дела об административном правонарушении рассматривают районные суды.
# >  Обратите внимание, что пассажиры могут не допускаться на борт воздушного судна без медицинского документа, подтверждающего отрицательный результат исследования методом ПЦР на COVID-19 (по решению авиакомпании-перевозчика).
# >  Согласно методическим указаниям Федерального агентства воздушного транспорта РФ, в целях предотвращения распространения COVID-19 рекомендуется не допускать скопления людей в аэровокзальных комплексах. В связи с этим встречающим и провожающим необходимо находиться в пассажирском терминале аэропорта не более 2 часов и, по возможности, сократить количество сопровождающих.
# >  Уведомляем Вас о том, что региональными властями могут быть введены дополнительные требования при организации воздушной перевозки пассажиров. Дополнительные детали организации воздушной перевозки пассажиров Вы можете уточнить в Управлении Роспотребнадзора региона, в который Вы прибываете, а также по телефонам регионального оперативного штаба по предотвращению распространения новой коронавирусной инфекции.
# >  В отношении всех прибывших граждан заполненные анкеты в суточный срок передаются в территориальный орган Роспотребнадзора по месту дальнейшего следования прибывших.
# >  Иностранным гражданам и лицам без гражданства, прибывающим в целях осуществления трудовой деятельности, выполнять требования по изоляции сроком на 14 календарных дней со дня прибытия на территорию Российской Федерации.
# >
# >  Вы можете позвонить на телефон оперативного штаба по коронавирусной инфекции в Вашем регионе, где исходя из Вашей конкретной ситуации будут даны рекомендации.
# >
# >  Чат-бот по коронавирусной инфекции работает в тестовом режиме. Если ответ на Ваш вопрос не является исчерпывающим, то мы просим Вас позвонить в Единый консультационный центр Роспотребнадзора 8-800-555-49-43 и дождаться ответа оператора.
# >
# >  Были рады Вам помочь.
# >
# >  С уважением и заботой о Вас, Роспотребнадзор.
# >Система автоматического ответа на вопросы по коронавирусной инфекции работает в тестовом режиме. Если ответ на Ваш вопрос не является исчерпывающим, то мы просим Вас повторно позвонить в Единый консультационный центр Роспотребнадзора 8-800-555-49-43 и дождаться ответа оператора.
# >Чат-бот Роспотребнадзора по коронавирусной инфекции: https://t.me/rospotrebnadzor_covid19_bot
# >
# >Были рады Вам помочь.
# >С уважением и заботой о Вас, Роспотребнадзор.

# %% [markdown]
# ##### Путём перемножения матрицы на вектор получим рейтинг вопросов, соответствующих запросу

# %%
rating = X_train.dot(query.T)
rating.T[0]
# Out:
# array([0.0619214 , 0.03147497, 0.01378502, ..., 0.13371664, 0.04082632,
#        0.05011642])

# %% [markdown]
# ##### Выведем top 20 самых близких вопросов и посмотрим на их номер связки

# %%
buf = list(zip(rating.T[0], answers_quest['join_num'].values))

for counter, val in enumerate(sorted(buf, key=lambda x: -x[0])):
    print(str(val[0]) + ": " + str(int(val[1])))
    if counter >= 20:
        break
# Out:
# 0.872465579747946: 6
# 0.8565766323060884: 37
# 0.8520109911095695: 308
# 0.8506964424341005: 308
# 0.5799577747276881: 308
# 0.5492405227665993: 308
# 0.46438488631836855: 6
# 0.4150960694233565: 308
# 0.4100833460262565: 57
# 0.38528174371736373: 308
# 0.3798309943298101: 308
# 0.3782031505152206: 37
# 0.3603318657711875: 308
# 0.3544300275326107: 6
# 0.34294649452108006: 6
# 0.33031712437246974: 5
# 0.29417124345478357: 308
# 0.29249321024959074: 308
# 0.2778121046352094: 6
# 0.2774299527163355: 308
# 0.2718401212379425: 308

# %% [markdown]
# ### __Задача 2__:
# Аналогичная задаче1 с другой метрикой
#
# Реализуйте поиск с метрикой *BM25* через умножение матрицы на вектор. Что должно быть в реализации:
#
# - проиндексированная база, где каждый документ представлен в виде вектора BM25
# - функция перевода входяшего запроса в вектор по метрике BM25
# - ранжирование докуменов по близости к запросу по убыванию

# %% [markdown]
# ##### Функции для векторизации единичного запроса

# %%
def vec_bm25(doc, dict_words):
    vec = np.zeros((1, len(dict_words)))
    doc = my_preprocess(doc)
    for word in doc.split(" "):
        if word in dict_words.keys():
            vec[0, dict_words[word][-1]] = 1
    return vec

# %% [markdown]
# ##### Обратно-индексированный словарь, по которому считаем метрики

# %%
def get_inverse_dict(mat):
    d = dict()
    mat = mat.toarray()
    for ind, word in enumerate(vectorizer.get_feature_names()):
        d[word] = [int(sum(mat[:, ind]))]
        for ind_j, doc_ind in enumerate(mat[:, ind].tolist()):
            if doc_ind != 0:
                d[word].append(doc_ind)
        d[word].append(ind)
    return d

# %% [markdown]
# ##### Функции для векторизации "тренировочного" множества

# %%
def bm25_vectorizer(tf_val, len_d, corpus_len, nq):
    IDF = np.log((corpus_len-nq+0.5) / (nq+0.5))
    TF = (tf_val * (k+1)) / (tf_val + k * (1-b+b*(len_d / avrdl)))
    return TF * IDF

# %% [markdown]
# ##### Создадим матрицу эмбеддингов

# %%
corpus_len = len(full_corpus)
avrdl = sum([len(i.split(" ")) for i in full_corpus]) / corpus_len

vectorizer = CountVectorizer()
X_train = vectorizer.fit_transform(full_corpus)
inverse_dict = get_inverse_dict(X_train)

mat = np.zeros((corpus_len, len(inverse_dict)))

for ind, doc in enumerate(full_corpus):
    tokens = doc.split(" ")
    tf_values = collections.Counter(tokens)
    len_d = len(tokens)
    for word in tokens:
        if word not in inverse_dict.keys():
            continue
        mat[ind, inverse_dict[word][-1]] = bm25_vectorizer(tf_values[word],
                                                         len_d,
                                                         corpus_len,
                                                         len(inverse_dict[word]) - 1)

# %% [markdown]
# ##### Также возьмём случайный запрос из тестовой выборки и посмотрим на рейтинг связок

# %%
query = vec_bm25(test.text.values[9], inverse_dict)
print(test.text.values[9])
# Out:
# Где в Ростове на Дону мы можем сделать обязательный тест на коронавирус по медицскомк полису без оплаты
# --
# Отправлено из Mail.ru для Android четверг, 03 сентября 2020г., 13:12 +03:00 от covid@78cge.ru :
#
# >Добрый день, Ваше сообщение зарегистрировано в системе под номером: 10853
# >Ваш вопрос:
# >У вас сказано, что добровольное взятие анализа платное, и взятие анализа без медицинских показаний тоже платное. А если у нас нет показаний и нас обязывают пройти этот тест - это же уже не добровольное прохождение, подскажите пожалуйста, где в Ростове на Дону мы сможем пройти обязательное тестирование по полису? Жду ответ -- Отправлено из Mail.ru для Android четверг, 03 сентября 2020г., 12:54 +03:00 от covid@78cge.ru :> Добрый день, Ваше сообщение зарегистрировано в системе под номером: 10844> Ваш вопрос:> Здравствуйте, мы 6 дней были в отпуске, а по приезду узнали об обязательном прохождении теста на коронавирус. Мы хотим его пройти, но у нас нет средств, а в поликлинике по страховому полису нам отказали. Завтра нужно в госуслуги уже подкрепить справку, о том, что мы не больны, но такой возможности в материальном плане у нас нет. Как нам поступить правильно, чтобы не получить штрафов за отсутствие справки, или как пройти тест без оплаты, возможно есть способ о котором мы не знаем? Жду ответ -- Отправлено из Mail.ru для Android > Ответ:> На основании подпункта 1.4 пункта 1 постановления Главного государственного санитарного врача РФ от 30 марта 2020 г. № 9 "О дополнительных мерах по недопущению распространения COVID-2019", организация лабораторной диагностики граждан в субъектах Российской Федерации с привлечением всех лабораторий организаций вне зависимости от их организационно-правовой формы, возложена на руководителей высшего исполнительного органа государственной власти субъектов Российской Федерации (регионы РФ). >   В настоящее время срок ПЦР-диагностики на новую коронавирусную инфекцию в соответствии с нормативно-правовыми актами Российской Федерации не установлен. Проведение анализа обычно занимает 1,5-2 дня. >   Однако, в ряде регионов Российской Федерации, из-за большого объема поступающих проб в лаборатории, сроки могут быть увеличены.>  >   Тестирование должны проходить в обязательном порядке все прибывшие из-за границы на территорию России после начала регулярного авиасообщения:>   - иностранные граждане - предоставляют медицинский документ (на русском или английском языках) об отрицательном ПЦР тесте на COVID - 19, выполненном не ранее чем за три дня до прибытия в Россию или медицинский документ, подтверждающий выявление антител иммуноглобулина G (при наличии). При отсутствии результатов отрицательного ПЦР теста - проходят ПЦР тест - в течении 3х дней с даты прибытия в Россию;>   - граждане РФ должны пройти ПЦР тест на ковид - в течении 3-х дней с даты прибытия.>   В случае любого ухудшения состояния здоровья гражданин должен незамедлительно обратиться за медицинской помощью по месту жительства без посещения медицинской организации и сообщить информацию о прибытии из-за границы.>   В отношении всех прибывших граждан заполненные анкеты в суточный срок передаются в территориальный орган Роспотребнадзора по месту дальнейшего следования прибывших.>  >   Кроме этого, тест на наличие коронавируса в обязательном порядке назначается по показаниям и исключительно врачом медицинской организации. Обязательному обследованию подлежат с учетом приоритетов, установленных санитарными правилами "СП 3.1.3597-20 Профилактика новой коронавирусной инфекции (COVID-19)": >   1) контактирующие с больным COVID–19;>   2) больным с диагнозом "внебольничная пневмония";>   3) лица, старше 65 лет, обратившимися за помощью с симптомами респираторного заболевания;>   4) медицинские работники, имеющие риски инфицирования COVID–19.>   Медицинские работники подлежат обязательному тестированию на коронавирусную инфекцию, поскольку они осуществляю работу и взаимодействие с носителями новой коронавирусной инфекции. Как правило, медицинских работников на постоянной основе тестирует работодатель - та медицинская организация, в которой работает медицинский сотрудник.>   Стоит учитывать, что в ряде регионов РФ нормативно-правовым актом органа здравоохранения (комитета, департамента, министерства) уточнен порядок тестирования медицинских работников (по в ...
# >Ответ:
# >Ниже будет представлена информация о всех необходимых действиях для прибывающих в Россию.
# >  Иностранным гражданам и лицам без гражданства:
# >  -при посадке в выполняющее международные воздушные перевозки воздушное судно, следующее в пункт назначения на территории Российской Федерации, в том числе в целях транзитного проезда через территорию Российской Федерации, и при пересечении Государственной границы Российской Федерации обеспечить наличие при себе медицинского документа (на русском или английском языках), подтверждающего отрицательный результат лабораторного исследования материала на COVID-19 методом полимеразной цепной реакции (ПЦР), отобранного не ранее чем за три календарных дня до прибытия на территорию Российской Федерации;
# >  -до прибытия на территорию Российской Федерации в целях обеспечения санитарно-карантинного контроля в пунктах пропуска через Государственную границу Российской Федерации обеспечить заполнение анкеты прибывающего на территорию Российской Федерации (рекомендуемый образец размещен на официальном сайте Роспотребнадзора).
# >  В случае невозможности представить медицинский документ на русском или английском языках допускается его представление на официальном языке государства регистрации организации, выдавшей такой медицинский документ, с переводом на русский язык, верность которого засвидетельствована консульским должностным лицом Российской Федерации.
# >
# >  Гражданам Российской Федерации, прибывающим на территорию Российской Федерации воздушным транспортом (за исключением членов экипажа воздушного судна, осуществляющего воздушную перевозку):
# >  -Обеспечить заполнение анкеты прибывающего на территорию Российской Федерации до прибытия на территорию Российской Федерации в целях обеспечения санитарно-карантинного контроля в пунктах пропуска через Государственную границу Российской Федерации.
# >  В целях оперативного прохождения санитарно-карантинного контроля в пунктах пропуска через Государственную границу Российской Федерации обеспечить заполнение на Едином портале государственных и муниципальных услуг (далее - ЕПГУ) ( https://www.gosuslugi.ru ) анкеты для прибывающего в Российскую Федерацию в электронном виде "Регистрация прибывающих в Российскую Федерацию" ( https://www.gosuslugi.ru/394604 ) до вылета в Российскую Федерацию (при приобретении билета, но не позднее регистрации на рейс).
# >  В течение трех календарных дней со дня прибытия на территорию Российской Федерации пройти лабораторное исследование на COVID-19 методом ПЦР и разместить информацию о результате лабораторного исследования на COVID-19 методом ПЦР в ЕПГУ, заполнив форму "Предоставление сведений о результатах теста на новую коронавирусную инфекцию для прибывающих на территорию Российской Федерации" ( https://www.gosuslugi.ru/400705/1 ).
# >  Несовершеннолетним можно зарегистрировать аккаунт на портале гос услуг. Стандартный профиль для детей старше 14 лет (требуется паспорт и СНИЛС) или упрощенный для детей до 14 лет (без подтверждающих документов). Анкеты на детей при сопровождении родителей создаются в личном кабинете родителя (можно активировать поля для ввода информации о детях). Дети следующие без родителей или сопровождающих лиц должны заполнить анкеты и загружать сведения о тестировании в личный аккаунт.
# >
# >  Граждане России в течении 3-х дней с момента прибытия в Россию должны пройти лабораторное исследование и загрузить результаты обследования на коронавирус (ПЦР-тест) в форму на портале Госуслуг. Это предусмотрено постановлением Главного государственного санитарного врача Российской Федерации от 18.03.2020 № 7 в редакции постановления от 27.07.2020 № 22. ПЦР-тестирование обязаны проходить все граждане РФ (в том числе, дети), которые въезжают на территорию Российской Федерации. Срок выполнения ПЦР-тестирования установлен на федеральном уровне и не может быть нарушен. Рекомендуем заранее записаться на сдачу ПЦР-теста на коронавирус (чтобы соблюсти установленный срок предоставления результатов). В ряде регионов ПЦР-тест можно сдать бесплатно, также по записи. Как правило, государственные поликлиники направляют на тестирование при наличии симптомов или по требованию Роспотребнадзора. В остальных случаях исследования проводятся на коммерческой основе. В ряде регионов услуга ПЦР теста доступна на территории аэропортов (в помещениях медицинского пункта). О возможности сдачи в аэропорту можно уточнить по телефонам справочных служб аэропортов (размещены на сайтах).
# >
# >  При положительном результате ПЦР теста на коронавирус, а также при появления любого ухудшения состояния здоровья в течение 14 календарных дней со дня прибытия на территорию России нужно незамедлительно обращаться за медицинской помощью по месту жительства (пребывания) БЕЗ посещения медицинских организаций. Обеспечить соблюдение требований по обязательной изоляции по месту жительства или фактическому пребыванию (в изолированном помещении, позволяющем исключить контакты с членами семьи и другими лицами, не подвергнутыми изоляции). Информация о положительных результатах передается в территориальные органы Роспотребнадзора и медицинские организации (поликлиники) по месту жительства для организации профилактических мер и медицинского наблюдения.
# >  В случае подгрузки на портал гос.услуг результатов ПЦР-тестирования в течении обозначенного срока и он является отрицательным делать ничего не нужно. В этом случае гражданин не обязан соблюдать изоляцию. Кроме того, отсутствует требование об изоляции и до момента получения результата теста при хорошем самочувствии.
# >  ВАЖНО: Граждане РФ не могут провести тестирование в иностранном государстве, с целью предоставления результатов в качестве выполненной обязанности, предусмотренной санитарно-эпидемиологическими нормами). Актуальная информация о перечне коммерческих лабораторий, допущенных к проведению исследований на COVID-19 лиц, не имеющих признаков инфекционного заболевания и не находящихся в прямом контакте с больным новой коронавирусной инфекции (COVID-19) размещен на сайте Роспотребнадзора (главная страница) - О новой коронавирусной инфекции - Перечень лабораторий, допущенных к исследованиям на новую коронавирусную инфекцию. Полная информация о стоимости и условиях доступна на сайтах организаций.
# >  За невыполнение обязанности ПЦР-тестирования в течении 3-х дней и отсутствие подгруженных результатов ПЦР-тестирования на граждан может быть наложен штраф в размере от 15000 до 40000 рублей (статья 6.3 КоАП РФ). Территориальные органы Роспотребнадзора уведомляют граждан о данном требовании и затем осуществляют контроль, в случае нарушения сроков - составляют протокол об административном правонарушении. В случае выявления должностными лицами нарушений обязательных требований Вас вызовут для ознакомления с протоколом об административном правонарушении. Уточнить и задать интересующие вопросы можно будет у должностного лица Управление Роспотребнадзора по вашему региону после вызова. Дела об административном правонарушении рассматривают районные суды.
# >  Обратите внимание, что пассажиры могут не допускаться на борт воздушного судна без медицинского документа, подтверждающего отрицательный результат исследования методом ПЦР на COVID-19 (по решению авиакомпании-перевозчика).
# >  Согласно методическим указаниям Федерального агентства воздушного транспорта РФ, в целях предотвращения распространения COVID-19 рекомендуется не допускать скопления людей в аэровокзальных комплексах. В связи с этим встречающим и провожающим необходимо находиться в пассажирском терминале аэропорта не более 2 часов и, по возможности, сократить количество сопровождающих.
# >  Уведомляем Вас о том, что региональными властями могут быть введены дополнительные требования при организации воздушной перевозки пассажиров. Дополнительные детали организации воздушной перевозки пассажиров Вы можете уточнить в Управлении Роспотребнадзора региона, в который Вы прибываете, а также по телефонам регионального оперативного штаба по предотвращению распространения новой коронавирусной инфекции.
# >  В отношении всех прибывших граждан заполненные анкеты в суточный срок передаются в территориальный орган Роспотребнадзора по месту дальнейшего следования прибывших.
# >  Иностранным гражданам и лицам без гражданства, прибывающим в целях осуществления трудовой деятельности, выполнять требования по изоляции сроком на 14 календарных дней со дня прибытия на территорию Российской Федерации.
# >
# >  Вы можете позвонить на телефон оперативного штаба по коронавирусной инфекции в Вашем регионе, где исходя из Вашей конкретной ситуации будут даны рекомендации.
# >
# >  Чат-бот по коронавирусной инфекции работает в тестовом режиме. Если ответ на Ваш вопрос не является исчерпывающим, то мы просим Вас позвонить в Единый консультационный центр Роспотребнадзора 8-800-555-49-43 и дождаться ответа оператора.
# >
# >  Были рады Вам помочь.
# >
# >  С уважением и заботой о Вас, Роспотребнадзор.
# >Система автоматического ответа на вопросы по коронавирусной инфекции работает в тестовом режиме. Если ответ на Ваш вопрос не является исчерпывающим, то мы просим Вас повторно позвонить в Единый консультационный центр Роспотребнадзора 8-800-555-49-43 и дождаться ответа оператора.
# >Чат-бот Роспотребнадзора по коронавирусной инфекции: https://t.me/rospotrebnadzor_covid19_bot
# >
# >Были рады Вам помочь.
# >С уважением и заботой о Вас, Роспотребнадзор.

# %%
rating = mat.dot(query.T)
rating.T[0]
# Out:
# array([53.79921003, 43.15390323, 29.81685085, ..., 48.51248618,
#        24.3228483 , 50.47812578])

# %%
buf = list(zip(rating.T[0], answers_quest['join_num'].values))

for counter, val in enumerate(sorted(buf, key=lambda x: -x[0])):
    print(str(val[0]) + ": " + str(int(val[1])))
    if counter >= 20:
        break
# Out:
# 270.4803782269762: 6
# 260.7573089866613: 37
# 251.63200801076133: 308
# 251.14614555252726: 308
# 165.773581167407: 308
# 162.20316093606698: 308
# 152.47634510890626: 308
# 146.77803645460517: 6
# 142.0738479047474: 308
# 139.24412919643268: 6
# 135.1826753143332: 37
# 133.82942779353738: 57
# 133.4118683403513: 5
# 125.02064154170101: 308
# 121.77526751281377: 308
# 114.55193596378707: 308
# 111.10297795015586: 1
# 110.00184803440646: 6
# 107.20922996864019: 308
# 104.26449334207283: 6
# 100.32660168545434: 308
